# %% [markdown]
# <a href="https://colab.research.google.com/github/son50git/PKT_003_Mastering-Matplotlib-3/blob/master/PKT_003_Rework_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set matpltolob to draw plots inline
# %matplotlib inline

# import matplotlib pyplot
import matplotlib.pyplot as plt

# import numpy
import numpy as np 

# import pandas
import pandas as pd

# import matplotlib
import matplotlib as mpl

# %%
from google.colab import drive, files
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f32015d-8040-42a0-84c3-38c0cb2934a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f32015d-8040-42a0-84c3-38c0cb2934a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bank.csv to bank.csv

# %%
data = pd.read_csv("bank.csv", sep=';')
print(data.shape)
data.head()
# Out:
# (4521, 17)
#    age          job  marital  education  ... pdays  previous poutcome   y
# 0   30   unemployed  married    primary  ...    -1         0  unknown  no
# 1   33     services  married  secondary  ...   339         4  failure  no
# 2   35   management   single   tertiary  ...   330         1  failure  no
# 3   30   management  married   tertiary  ...    -1         0  unknown  no
# 4   59  blue-collar  married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
data.describe()
# Out:
#                age       balance  ...        pdays     previous
# count  4521.000000   4521.000000  ...  4521.000000  4521.000000
# mean     41.170095   1422.657819  ...    39.766645     0.542579
# std      10.576211   3009.638142  ...   100.121124     1.693562
# min      19.000000  -3313.000000  ...    -1.000000     0.000000
# 25%      33.000000     69.000000  ...    -1.000000     0.000000
# 50%      39.000000    444.000000  ...    -1.000000     0.000000
# 75%      49.000000   1480.000000  ...    -1.000000     0.000000
# max      87.000000  71188.000000  ...   871.000000    25.000000
#
# [8 rows x 7 columns]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.hist(data.balance)
# Out:
# (array([4.111e+03, 3.400e+02, 4.700e+01, 1.700e+01, 4.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-3313. ,  4137.1, 11587.2, 19037.3, 26487.4, 33937.5, 41387.6,
#         48837.7, 56287.8, 63737.9, 71188. ]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(data.balance)
plt.xlabel('Customer')  # where the Customer data coming from?
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data2 = data[0:30]['balance']
data2.hist()

# %%
data2
# Out:
# 0     1787
# 1     4789
# 2     1350
# 3     1476
# 4        0
# 5      747
# 6      307
# 7      147
# 8      221
# 9      -88
# 10    9374
# 11     264
# 12    1109
# 13     502
# 14     360
# 15     194
# 16    4073
# 17    2317
# 18    -221
# 19     132
# 20       0
# 21      16
# 22     106
# 23      93
# 24     543
# 25    5883
# 26     627
# 27     696
# 28     784
# 29     105
# Name: balance, dtype: int64

# %%
data2.plot()
# keeps track of numeric values of "id"
# plt.plot() wouldn't work as data2 is not a DataFrame but a Series

# %%
plt.style.use('ggplot')

plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.style.use('seaborn')

plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.style.use('fivethirtyeight')

plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# np.linspace # Return evenly spaced numbers over a specified interval.
# numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)[source]
np.linspace(2.0, 3.0, num=5)
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  ])

# %%
th = np.linspace(0, 2*np.pi, 128)
th
# Out:
# array([0.        , 0.0494739 , 0.0989478 , 0.1484217 , 0.1978956 ,
#        0.2473695 , 0.2968434 , 0.3463173 , 0.3957912 , 0.4452651 ,
#        0.494739  , 0.5442129 , 0.5936868 , 0.6431607 , 0.6926346 ,
#        0.7421085 , 0.7915824 , 0.8410563 , 0.8905302 , 0.9400041 ,
#        0.989478  , 1.0389519 , 1.0884258 , 1.1378997 , 1.1873736 ,
#        1.2368475 , 1.2863214 , 1.3357953 , 1.3852692 , 1.4347431 ,
#        1.484217  , 1.5336909 , 1.5831648 , 1.6326387 , 1.6821126 ,
#        1.7315865 , 1.7810604 , 1.8305343 , 1.8800082 , 1.9294821 ,
#        1.978956  , 2.0284299 , 2.0779038 , 2.1273777 , 2.1768516 ,
#        2.2263255 , 2.2757994 , 2.3252733 , 2.3747472 , 2.4242211 ,
#        2.473695  , 2.5231689 , 2.5726428 , 2.6221167 , 2.6715906 ,
#        2.7210645 , 2.7705384 , 2.8200123 , 2.8694862 , 2.9189601 ,
#        2.968434  , 3.0179079 , 3.0673818 , 3.1168557 , 3.1663296 ,
#        3.2158035 , 3.2652774 , 3.3147513 , 3.3642252 , 3.4136991 ,
# ...

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.set_title('Title')

ax.plot(th, np.cos(th), label='C1')
ax.plot(th, np.sin(th), label='C2')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.set_title('Title', color='C0')

ax.plot(th, np.cos(th), 'C1', label='C1')
ax.plot(th, np.sin(th), 'C2', label='C2')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.set_title('Title', color='b')

ax.plot(th, np.cos(th), 'y', label='y')
ax.plot(th, np.sin(th), 'r', label='r')
ax.legend()

# %%
# plt.subplot()
# A 3-digit integer. The digits are interpreted as if given separately as three single-digit integers, 
# i.e. fig.add_subplot(235) is the same as fig.add_subplot(2, 3, 5). Note that this can only be used 
# if there are no more than 9 subplots.

# %%
plt.subplot(131)  # 1 x 3, 1st
plt.subplot(132)  # 1 x 3, 2nd
plt.subplot(133)  # 1 x 3, 3rd

# %%
plt.subplot(311)  # 3 x 1, 1st
plt.subplot(312)  # 3 x 1, 2nd
plt.subplot(313)  # 3 x 1, 3rd

# %%
plt.subplot(231)
plt.subplot(232)
plt.subplot(233)
plt.subplot(235)
plt.subplot(236)

# %%
plt.subplot2grid((2,2), (0,0))
plt.subplot2grid((2,2), (1,0))
plt.subplot2grid((2,2), (0,1))

# %%
plt.subplot2grid((2,2), (0,0))
plt.subplot2grid((2,2), (1,0))
plt.subplot2grid((2,2), (1,1))

# %%
plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
mpl.rcParams['lines.linewidth'] = 1 # working
mpl.rcParams['lines.color'] = 'r'  # not working

plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
mpl.rc('lines', linewidth=1, color='r')
mpl.rcdefaults()

plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
mpl.get_configdir()
# Out:
# '/root/.config/matplotlib'

# %%
plt.style.reload_library()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.plot(data.balance)
plt.xlabel('Customer')
plt.ylabel('Balance')
plt.title('Customer Balance')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data.balance.plot.hist()
plt.ylabel('Customer')
plt.xlabel('Balance')
plt.title('Customer Balance Distribution')
plt.show()

# %%
data.balance.plot.hist(grid=True)
plt.ylabel('Customer')
plt.xlabel('Balance')
plt.title('Customer Balance Distribution')
plt.show()

# %%
data.balance.plot.hist(grid=True, bins=15, rwidth=0.9,
                   color='#607c8e')
plt.ylabel('Customer')
plt.xlabel('Balance')
plt.title('Customer Balance Distribution')
plt.show()

# %%
data.balance.plot.hist(grid=True, bins=15, rwidth=0.9,
                   color='#607c8e')
plt.ylabel('Customer')
plt.xlabel('Balance')
plt.title('Customer Balance Distribution')
plt.grid(color='b', linestyle='-', linewidth=0.5)
plt.show()

# %%
# Calling this function with no arguments (e.g. xticks()) is the pyplot equivalent 
# of calling get_xticks and get_xticklabels on the current axes
data.balance.plot.hist(grid=True, bins=15, rwidth=0.9, color='#607c8e')
plt.ylabel('Customer')
plt.xlabel('Balance')
plt.title('Customer Balance Distribution')
plt.grid(color='b', linestyle='-', linewidth=1)
plt.xticks()  
plt.show()

# %%
data.balance.plot.hist(grid=True, bins=15, rwidth=0.9,
                   color='#607c8e')
plt.ylabel('Customer')
plt.xlabel('Balance')
plt.title('Customer Balance Distribution')
plt.grid(color='b', linestyle='-', linewidth=1)
plt.xticks(np.arange(0, 1000000, step=100000))
plt.show()

# %%
plt.figure(1, figsize=(3,3))
ax = plt.subplot(111)

ax.annotate("Here",
            xy=(0.2, 0.2), xycoords='data',
            xytext=(0.8, 0.8), textcoords='data',
            size=20, va="center", ha="center",
            arrowprops=dict(arrowstyle="simple",
                            connectionstyle="arc3,rad=-0.2"), 
            )

plt.show()

# %%
fig, ax = plt.subplots()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
ax.set_ylim(-2, 2)
plt.show()
